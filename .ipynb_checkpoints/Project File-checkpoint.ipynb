# %% [markdown]
# # Classifying MBTI Based on Social Media Use
# #### ECON 323 003 Quantitative Economic Modelling with Data Science Application
#
# Group Members: Zaya Baatarzaya (45131414) | Kim Tan Palanca (98857568) | Vivian Vu (92958461) | Sophia Zhang (65921389)

# %% [markdown]
# # Introduction

# %% [markdown]
# Personality is defined as the characteristics and behavior of an individual that encompass their emotional patterns (American Psychology Association, 2022). Over time, many mechanisms and indicators have been discovered that break down the intricacies of a personality into general categories, one of which is the Myers-Briggs Type Indicator (MBTI) test. This personality instrument was developed by Isabel Briggs Myers and Katherine Briggs to bring true Carl Jung’s theory of personalities having basic differences.
#
# There are four main divisions within the MBTI classification with two contrasting traits in each division. Depending on the traits satisfied by an individual, a four-letter code that combines one trait from each of the divisions will determine the individual’s personality type. The divisions and types are listed as follows:
#
# **Table 1.** <br>
# *Myers-Briggs Type Indicators*</p>
#
#
# Category  | Traits | Description
# ------------- | ------------- | -------------
# Favorite World  | Introvert (I) or Extrovert (E) |Preference to focus on the outer world or one’s inner world.
# Information  | Sensing (S) or Intuition (N) | Preference to focus on and take in basic information or to interpret and add meaning.
# Decisions | Thinking (T) or Feeling (F) |Preference to first look at logic and consistency or to first look at the people and special circumstances when making decisions.
# Structure | Judging (J) or Perceiving (P) | Preference to get things decided or to stay open to new information and options when dealing with the outside world.
#
# Note. The information in this table is taken from The Myers & Briggs Foundation. (2022, November). MBTI® basics. The Myers & Briggs Foundation. Retrieved April 3, 2023, from https://www.myersbriggs.org/my-mbti-personality-type/mbti-basics/
#
# There are many aspects of one’s behavior that determine their personality type including their writing style (Gupta et al., 2019). With the popularity of social media where people have the freedom to share their thoughts and stories, many individuals of varying personality types can arise in a single social media platform (Nisha et al., 2021). The dataset “(MBTI) Myers-Briggs Personality Type Dataset” by user Mitchell J presents data collected from the PersonalityCafe Forum which includes an individual’s MBTI and their last 50 posts on the forum. Utilizing the techniques learned in the ECON 323 course, this project aims to delve into the relationship between Myers Briggs Type Indicators (MBTI) and social media use. More specifically, to predict an individual’s MBTI based on their posts on social media.

# %% [markdown]
# # Cleaning

# %% [markdown]
# Before performing any analysis, it is critical to import the dataset and any packages used throughout the study. As mentioned in the introduction, the project will manipulate the “(MBTI) Myers-Briggs Personality Type Dataset” by user Mitchell J. Note that we first separated the original data set into two CSV files: one with only the MBTI type and another with only the posts. We then imported the two files into this notebook.

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

import seaborn as sns

from sklearn import (linear_model, metrics, neural_network, pipeline, preprocessing, model_selection)

from bs4 import BeautifulSoup
import nltk
import string
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('wordnet')

from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jupyter/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
types = pd.read_csv("mbti_types.csv")
posts = pd.read_csv("mbti_posts.csv")

print(types.head(3))
print(posts.head(3))
# Out:
#    type
# 0  INFJ
# 1  ENTP
# 2  INTP
#                                                posts
# 0  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1  'I'm finding the lack of me in these posts ver...
# 2  'Good one  _____   https://www.youtube.com/wat...

# %% [markdown]
# As shown in the output above, all the 50 posts in the `posts` CSV file are stored in one column. For this study, howwever, each nth post of a user will be considered as one variable, meaning that the columns will be labelled as the post number, numbered 0 to 49. Thus, each row in the `posts` CSV file will be seaparated by `"|||"`.

# %%
sep_posts = posts['posts'].str.split("\|\|\|", expand = True)

sep_posts.head(3)
# Out:
#                                                   0   \
# 0        'http://www.youtube.com/watch?v=qsXHcwe3krw
# 1  'I'm finding the lack of me in these posts ver...
# 2  'Good one  _____   https://www.youtube.com/wat...
#
#                                                   1   \
# 0  http://41.media.tumblr.com/tumblr_lfouy03PMA1q...
# 1  Sex can be boring if it's in the same position...
# 2  Of course, to which I say I know; that's my bl...
#
#                                                   2   \
# 0  enfp and intj moments  https://www.youtube.com...
# 1               Giving new meaning to 'Game' theory.
# 2  Does being absolutely positive that you and yo...
#
#                                                   3   \
# 0  What has been the most life-changing experienc...
# 1  Hello *ENTP Grin*  That's all it takes. Than w...
# 2                No, I didn't; thank you for a link!
#
#                                                   4   \
# 0  http://www.youtube.com/watch?v=vXZeYwwRDw8   h...
# 1  This + Lack of Balance and Hand Eye Coordination.
# 2  So-called Ti-Si loop (and it can stem from any...
#
#                                                   5   \
# 0               May the PerC Experience immerse you.
# 1  Real IQ test I score 127. Internet IQ tests ar...
# 2  Have you noticed how peculiar vegetation can b...
#
#                                                   6   \
# 0  The last thing my INFJ friend posted on his fa...
# 1  You know you're an ENTP when you vanish from a...
# 2               The Smiths ‚Äì Never Had No One Ever
#
#                                                   7   \
# 0  Hello ENFJ7. Sorry to hear of your distress. I...
# 1  http://img188.imageshack.us/img188/6422/6020d1...
# 2  I often find myself spotting faces on marble t...
#
#                                                   8   \
# 0  84389  84390  http://wallpaperpassion.com/uplo...
# 1  http://img.adultdvdtalk.com/813a0c6243814cab84c51
# 2  This 5 year-old sentence is an incredibly accu...
#
#                                                   9   ...    79    80    81  \
# 0                                 Welcome and stuff.  ...  None  None  None
# 1  I over think things sometimes. I go by the old...  ...  None  None  None
# 2  I haven't visited this website in the last 3 y...  ...  None  None  None
#
#      82    83    84    85    86    87    88
# 0  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None
#
# [3 rows x 89 columns]

# %% [markdown]
# Note that there are 89 columns when the expected number of columns should be 50 given that description of the dataset used for this analysis claims to only collect the last 50 posts. After inspecting the `sep_posts` dataframe, some rows had less then 50 posts, while other rows had more then 50. The largest concern with the `sep_posts` dataframe is that there are some empty cells in between the non-empty cells from some rows. An example of this would be row 7257, which is shown below:

# %%
sep_posts.iloc[7257][0:60]
# Out:
# 0     'This is great and makes a lot of sense, I fee...
# 1                                I laugh in my sleep :P
# 2     I would go back to earlier this year so that I...
# 3     can I just say, this is such an INTJ thread it...
# 4     it's been non existent, but now im just starti...
# 5     This is really interesting, I'm definitely a N...
# 6     Buddy the Elf Chris             - Where Dreams...
# 7     Well my cognitive function results were pretty...
# 8     cue5c I know how you feel. I'm in a similar si...
# 9     I loveeeee German, I'm fluent and was even abl...
# 10    I really understand what you guys are talking ...
# 11    I'm REALLY good at reading other people when i...
# 12               This guy's channel is so helpful! haha
# 13    Lets just say that over the last year I might ...
# 14                  I would definitely be a Cockatoo :D
# 15    I don't think you're personality can change, I...
# 16    Your Cognitive Functions: Extroverted Intuitio...
# 17
# 18
# 19
# 20
# 21
# 22
# 23
# 24
# 25                      12.92 Extroverted Feeling (Fe)
# 26
# 27
# 28
# 29
# 30
# 31
# 32
# 33
# 34                    12.84 Introverted Feeling (Fi)...
# 35    I took them!!! mwahaha! :P  What is your reaso...
# 36    Days went one of 2 ways:  A) no one would answ...
# 37    Degree: Bachelor of Music  Past careers: telem...
# 38    The best thing that happened to me was definit...
# 39                                    lol im kidding :P
# 40    I'm 21 (almost 22) and graduating from college...
# 41    Voldemort! MWAHAHAHAHAHAHHAHAHAHAHAHAHAHAHA   lol
# 42    Everything here is so true!!! I'm glad someone...
# 43    I always get ENFP, but when I'm in an off mood...
# 44             Ah you're right! Then it'd be perfect :D
# 45    My turning point was when I met a group of peo...
# 46    They're really fun and crazy friends, but I've...
# 47    1) It would be sunny with clouds and a warm br...
# 48                                    weeeeeeeeeeeee!!!
# 49    & I'll sneak up behind you and push you after ...
# 50    I love INTJs, 2 of my best friends are that ty...
# 51    An INTJ I know goes into this really dark, bro...
# 52    I chose mine because I love looking at the nig...
# 53    I'm an xNFP (leaning toward E now, but I tend ...
# 54    That link's really interesting, my Ne and Fi a...
# 55    Your Cognitive Functions: Extroverted Intuitio...
# 56
# 57
# 58
# 59
# Name: 7257, dtype: object

# %% [markdown]
# To mitigate this issue, the empty cells of each row will be dropped and the remaining non-empty rows will shift to fill in the empty spaces.

# %%
def shift(row):
    row = row.dropna()
    row = pd.Series(row.values)
    return row

# %%
sep_posts = sep_posts.apply(lambda x: x.str.strip()).replace('', np.nan).dropna(how='all', axis=1)
sep_posts2 = sep_posts.apply(shift, axis = 1)

# %% [markdown]
# It should also be noted that because the posts were all initially compiled into one string, there is a opening apostrophe and a closing apostrophe in the first and last post of each row, respectively. To ensure that these will not hinder the data analysis, the characters will be removed from their respective cells.

# %%
def remove_first_apostrophe(s):
    if s[0] == "'":
        post = s[1:]
    else:
        post = s
    return post

# %%
sep_posts2[0] = sep_posts2[0].apply(remove_first_apostrophe)
sep_posts2.iloc[:, -1] = sep_posts2.iloc[:, -1].apply(lambda x: x[:-1] if isinstance(x, str) else x)

# %% [markdown]
# Lastly, the two files--`types` and `sep_posts2`-- will concatenate into one dataframe using the `pd.concat` function.

# %%
data = pd.concat([types, sep_posts2], axis=1)
data
# Out:
#       type                                                  0  \
# 0     INFJ         http://www.youtube.com/watch?v=qsXHcwe3krw
# 1     ENTP  I'm finding the lack of me in these posts very...
# 2     INTP  Good one  _____   https://www.youtube.com/watc...
# 3     INTJ  Dear INTP,   I enjoyed our conversation the ot...
# 4     ENTJ                                      You're fired.
# ...    ...                                                ...
# 8670  ISFP        https://www.youtube.com/watch?v=t8edHB_h908
# 8671  ENFP  So...if this thread already exists someplace e...
# 8672  INTP  So many questions when i do these things.  I w...
# 8673  INFP  I am very conflicted right now when it comes t...
# 8674  INFP  It has been too long since I have been on pers...
#
#                                                       1  \
# 0     http://41.media.tumblr.com/tumblr_lfouy03PMA1q...
# 1     Sex can be boring if it's in the same position...
# 2     Of course, to which I say I know; that's my bl...
# 3     Dear ENTJ sub,   Long time no see.  Sincerely,...
# 4     That's another silly misconception. That appro...
# ...                                                 ...
# 8670  IxFP just because I always think of cats as Fi...
# 8671  Ooops...I guess I didn't look too hard because...
# 8672  I worked in a brewery for a couple years here....
# 8673  If I had to guess for my closest friends:  1. ...
# 8674         http://www.youtube.com/watch?v=6EEW-9NDM5k
#
#                                                       2  \
# 0     enfp and intj moments  https://www.youtube.com...
# 1                  Giving new meaning to 'Game' theory.
# 2     Does being absolutely positive that you and yo...
# 3     None of them. All other types hurt in deep exi...
# 4     But guys... he REALLY wants to go on a super-d...
# ...                                                 ...
# 8670  Especially on websites that have become a have...
# 8671  So, this came up in the You Know You're An ENF...
# 8672  I am going to summon the great and powerful mr...
# 8673  What you said in the last paragraph ... as a t...
# 8674                Overwhelmed by the world around me.
#
#                                                       3  \
# 0     What has been the most life-changing experienc...
# 1     Hello *ENTP Grin*  That's all it takes. Than w...
# 2                   No, I didn't; thank you for a link!
# 3     Probably a sliding scale that depends on indiv...
# 4            Never mind. Just go on permanent vacation.
# ...                                                 ...
# 8670  I'm such a nerd. I've been learning Dutch on D...
# 8671                         I know that I liked UP. :D
# 8672  This thread is obviously about the textbook de...
# 8673  I can't say that I had much trouble with my co...
# 8674  In one dream I have had I was being chased by ...
#
#                                                       4  \
# 0     http://www.youtube.com/watch?v=vXZeYwwRDw8   h...
# 1     This + Lack of Balance and Hand Eye Coordination.
# 2     So-called Ti-Si loop (and it can stem from any...
# 3     Draco Malfoy also. I'd say he's either 358 or ...
# 4     Two months? I wouldn't be crazy about the idea...
# ...                                                 ...
# 8670    Duolingo is the shit!  Oh my god I love this XD
# 8671  I choose feeding myself joy over beating mysel...
# 8672  Stand up for yourself. You asked for the time ...
# 8673  I do eat meat, and I do feel guilty about it. ...
# 8674  Well now My Avatar is a Doctor Who Clockwork C...
#
#                                                       5  \
# 0                  May the PerC Experience immerse you.
# 1     Real IQ test I score 127. Internet IQ tests ar...
# 2     Have you noticed how peculiar vegetation can b...
# 3     I'm either 358 or 385, though in which stackin...
# 4     Lol. Its not like our views were unsolicited. ...
# ...                                                 ...
# 8670  Right wingers do this because they lack politi...
# 8671  [QUOTE=Pucca;2951774]I've never seen it.:shock...
# 8672  Lol excellent thread @NT the DC. I love watchi...
# 8673  Well I am in the SAME boat as you except I tea...
# 8674  1st - Thanks for your reply, I appreciate all ...
#
#                                                       6  \
# 0     The last thing my INFJ friend posted on his fa...
# 1     You know you're an ENTP when you vanish from a...
# 2                  The Smiths ‚Äì Never Had No One Ever
# 3     I'm not particularly introverted or extraverte...
# 4     Sometimes I just really like impoverished rap ...
# ...                                                 ...
# 8670  I doubt it, but if they are real then I hope t...
# 8671  That's hilarious. hahaha I used to pretend I h...
# 8672  The thing with relationships is that you spend...
# 8673  Exactly if God truly created one man and one w...
# 8674  Yea, Not Doing the Iron Man Thing xD  Thanks f...
#
#                                                       7  \
# 0     Hello ENFJ7. Sorry to hear of your distress. I...
# 1     http://img188.imageshack.us/img188/6422/6020d1...
# 2     I often find myself spotting faces on marble t...
# 3     Dear Type 9 INFP,  Your absolute admiration of...
# 4     I probably would have lost it too. His stonewa...
# ...                                                 ...
# 8670  I would agree that both are likely related to ...
# 8671               WOOO!  I'd love to be the TARDIS! :D
# 8672  Thinking: A man plants a fruit tree because it...
# 8673  As per the 10 books that have stayed with you ...
# 8674  Thanks :)  I think I needed some humour. I mig...
#
#                                                       8  ...  \
# 0     84389  84390  http://wallpaperpassion.com/uplo...  ...
# 1     http://img.adultdvdtalk.com/813a0c6243814cab84c51  ...
# 2     This 5 year-old sentence is an incredibly accu...  ...
# 3     2% still means about 1/50 people. I've probabl...  ...
# 4     I would have just taken the project and gave t...  ...
# ...                                                 ...  ...
# 8670  Both Nazi Germany and the Soviet Union were ex...  ...
# 8671  This is from my signature (actually, just look...  ...
# 8672  Well I think you can appreciate an Einstein qu...  ...
# 8673  These are some amazing lists, and I'm partiall...  ...
# 8674  I don't really know how to judge personality t...  ...
#
#                                                      49   50   51   52   53  \
# 0     Move to the Denver area and start a new life f...  NaN  NaN  NaN  NaN
# 1     Psychologist don't keep me around long enough ...  NaN  NaN  NaN  NaN
# 2     ISTP?   http://www.youtube.com/watch?v=7ghqoYx...  NaN  NaN  NaN  NaN
# 3                                                 Lol.'  NaN  NaN  NaN  NaN
# 4     The brevity of my posts is because you don't t...  NaN  NaN  NaN  NaN
# ...                                                 ...  ...  ...  ...  ...
# 8670  Also, what moderate even means changes dependi...  NaN  NaN  NaN  NaN
# 8671  My lovelife is nonexistant.   Recently (basica...  NaN  NaN  NaN  NaN
# 8672  This is a loaded question.   As for me I'm 19 ...  NaN  NaN  NaN  NaN
# 8673  Wait, leafstone, third volume of 1Q84?  Was th...  NaN  NaN  NaN  NaN
# 8674  I would never want to turn off my emotions. so...  NaN  NaN  NaN  NaN
#
#        54   55   56   57   58
# 0     NaN  NaN  NaN  NaN  NaN
# 1     NaN  NaN  NaN  NaN  NaN
# 2     NaN  NaN  NaN  NaN  NaN
# 3     NaN  NaN  NaN  NaN  NaN
# 4     NaN  NaN  NaN  NaN  NaN
# ...   ...  ...  ...  ...  ...
# 8670  NaN  NaN  NaN  NaN  NaN
# 8671  NaN  NaN  NaN  NaN  NaN
# 8672  NaN  NaN  NaN  NaN  NaN
# 8673  NaN  NaN  NaN  NaN  NaN
# 8674  NaN  NaN  NaN  NaN  NaN
#
# [8675 rows x 60 columns]

# %% [markdown]
# Despite applying the `shift` function to the `sep_posts` dataframe, there are still more than 50 columns in total. This being said, it will now be assumed that the data collection implies an average of the last 50 posts were collected from each user, with some having less than 50 posts and others having more.

# %% [markdown]
# # Data Descriptions

# %% [markdown]
# Given the large number of observations in the dataset, it is beneficial first to understand the distribution of how many posts are given for each MBTI type to provide understanding of the representation of each MBTI type and any possible uneven distribution when concluding the analysis.

# %%
mbti_types = ['estj', 'entj', 'esfj', 'enfj', 
              'istj', 'isfj', 'intj', 'infj',
              'estp', 'entp', 'esfp', 'enfp', 
              'istp', 'intp', 'isfp', 'infp']

mbti=[]
for x in mbti_types:
    l = x.upper()
    mbti += [l]

print(mbti)
# Out:
# ['ESTJ', 'ENTJ', 'ESFJ', 'ENFJ', 'ISTJ', 'ISFJ', 'INTJ', 'INFJ', 'ESTP', 'ENTP', 'ESFP', 'ENFP', 'ISTP', 'INTP', 'ISFP', 'INFP']

# %%
group_data = data.groupby("type")

n = []
for x in mbti:
    mbti_group = group_data.get_group(f"{x}")
    obs = mbti_group.count().sum()
    n += [obs]

n_obs = pd.DataFrame([np.array(mbti), np.array(n)]).T
n_obs.columns = ["type", "n obeservations"]

# %%
plt.subplots(figsize= (9,5))
ax = sns.countplot(data, x = "type", order=mbti)
ax.bar_label(ax.containers[0], labels = n)
plt.xlabel("MBTI Type")
plt.ylabel("Number of Posts")
plt.title("Representation of Each MBTI in The Dataset")
# Out:
# Text(0.5, 1.0, 'Representation of Each MBTI in The Dataset')

# %% [markdown]
# From this graph, it should be noted that there is a larger representation of the INTJ, INFJ, INTP, and INFP types while a much smaller representation of the ESTJ,ESFJ,ESTP, and ESFP types.

# %% [markdown]
# ## Word Counts of Posts from Each MBTI

# %% [markdown]
# The code below defines a function that will count the words of each post in the data, excluding spaces and punctuations.

# %%
data_posts = data.drop(columns = ["type"])
# Out:
# 790
# /tmp/ipykernel_498/3387761993.py:7: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(string, 'html.parser')
# /tmp/ipykernel_498/3387761993.py:7: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(string, 'html.parser')

# %%
def word_count(dp):
    total_count=[]
    for n in range(len(dp)):
        posts_list = [x for x in dp.iloc[n]]
        word_count = 0
        for p in posts_list:
            if isinstance(p, str):
                soup = BeautifulSoup(p, 'html.parser')
                text = soup.get_text()
                words = word_tokenize(text)
                word_count += len(words)
        total_count += [word_count]
    return total_count

# %%
data["Word Count"] = word_count(data_posts)
# Out:
# /tmp/ipykernel_498/456000169.py:8: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(p, 'html.parser')
# /tmp/ipykernel_498/456000169.py:8: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(p, 'html.parser')

# %%
data_word_count = data.drop(columns = [x for x in range(59)])
data_word_count
# Out:
#       type  Word Count
# 0     INFJ         790
# 1     ENTP        1465
# 2     INTP        1067
# 3     INTJ        1350
# 4     ENTJ        1211
# ...    ...         ...
# 8670  ISFP        1015
# 8671  ENFP        1726
# 8672  INTP        1219
# 8673  INFP        2084
# 8674  INFP        1648
#
# [8675 rows x 2 columns]

# %% [markdown]
# The summary statistics of the word counts for the posts of each MBTI, along with a boxplot visualization are generated to provide a description on the average and range of the length of a post of each MBTI.

# %%
summary_stats = pd.DataFrame()
for m in mbti:
    stats = data_word_count.groupby("type").get_group(f"{m}").describe()
    summary_stats[f"{m}"] = stats

print(summary_stats)
# Out:
#               ESTJ         ENTJ         ESFJ         ENFJ         ISTJ  \
# count    39.000000   231.000000    42.000000   190.000000   205.000000
# mean   1522.153846  1516.077922  1594.261905  1606.331579  1517.195122
# std     346.634081   335.586745   419.385617   363.508041   385.594004
# min     778.000000   438.000000   441.000000   245.000000   231.000000
# 25%    1281.500000  1343.500000  1348.000000  1419.000000  1303.000000
# 50%    1597.000000  1576.000000  1645.000000  1671.000000  1573.000000
# 75%    1726.500000  1747.500000  1927.250000  1870.000000  1792.000000
# max    2186.000000  2128.000000  2157.000000  2217.000000  2135.000000
#
#               ISFJ         INTJ         INFJ         ESTP         ENTP  \
# count   166.000000  1091.000000  1470.000000    89.000000   685.000000
# mean   1554.921687  1490.219982  1592.265986  1450.022472  1503.181022
# std     406.666075   367.860882   344.925186   371.076137   330.105059
# min     227.000000   158.000000   148.000000   392.000000   254.000000
# 25%    1333.500000  1278.500000  1410.250000  1194.000000  1309.000000
# 50%    1652.500000  1551.000000  1666.000000  1522.000000  1547.000000
# 75%    1855.000000  1770.500000  1842.000000  1714.000000  1756.000000
# max    2161.000000  2213.000000  2212.000000  2126.000000  2213.000000
#
#               ESFP         ENFP         ISTP         INTP         ISFP  \
# count    48.000000   675.000000   337.000000  1304.000000   271.000000
# mean   1298.416667  1579.115556  1462.008902  1495.233896  1435.339483
# std     471.495892   351.731733   374.070312   352.086847   399.501044
# min     355.000000    46.000000   220.000000    80.000000    84.000000
# 25%     930.750000  1398.500000  1232.000000  1282.000000  1189.000000
# 50%    1355.000000  1631.000000  1519.000000  1546.000000  1498.000000
# 75%    1687.000000  1833.500000  1744.000000  1763.000000  1740.000000
# max    2081.000000  2272.000000  2188.000000  2201.000000  2180.000000
#
#               INFP
# count  1832.000000
# mean   1553.536026
# std     356.738777
# min      11.000000
# 25%    1352.000000
# 50%    1609.500000
# 75%    1812.250000
# max    2231.000000

# %%
plt.subplots(figsize= (9,5))
box = sns.boxplot(data=data_word_count, x="type", y="Word Count", order = mbti)
line = sns.lineplot(x=mbti, y=summary_stats.loc["mean"], sort = mbti, errorbar = None, marker = "o", estimator = 'mean', legend = True)
plt.xlabel("MBTI Type")
plt.ylabel("Word Count")
plt.title("Boxplots of Word Counts of Social Media Posts Based on MBTI Type")
# Out:
# Text(0.5, 1.0, 'Boxplots of Word Counts of Social Media Posts Based on MBTI Type')

# %% [markdown]
# ### Word Clouds

# %% [markdown]
# When determining the most commond words for each MBTI, it is essential that the chosen words have variation to provide a clearer distnction between the MBTI types. This being said, words such as "the," "a," "an," "is," and "to" will be excluded in the analysis. Words in each post will also automatically be converted to their dictonary form for simplicity.

# %%
stopwords = set(nltk.corpus.stopwords.words('english'))
stopwords = stopwords.union(set(string.punctuation))

wnl = nltk.WordNetLemmatizer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[98], line 2
#       1 stopwords = set(nltk.corpus.stopwords.words('english'))
# ----> 2 stopwords = stopwords.union(set(string.punctuation))
#       4 wnl = nltk.WordNetLemmatizer()
#
# AttributeError: 'float' object has no attribute 'punctuation'

# %% [markdown]
# A newly defined function `text_prep` is then created, compiling the functions set in the cell above, that will clean, tokenize, remove stopwords, and lemmatize the words in each post.

# %%
def text_prep(txt):
    soup = BeautifulSoup(txt, "lxml")
    [s.extract() for s in soup('style')]
    txt=soup.text
    txt = txt.lower()
    tokens = [token for token in nltk.tokenize.word_tokenize(txt)]
    tokens = [token for token in tokens if not token in stopwords]
    tokens = [wnl.lemmatize(token) for token in tokens]
    if (len(tokens)==0):
        tokens = ["EMPTYSTRING"]
    return(tokens)

# %% [markdown]
# In this report, the ten most common words used by each MBTI will be chosen. These words will then be displayed on a bar graph to determine their frequencies in posts, along with a word cloud for further visualization.

# %%
fig = plt.figure(figsize=(10, 60))
spec = fig.add_gridspec(ncols=2, nrows=16)
for i, t in enumerate(mbti):
    ax0 = fig.add_subplot(spec[i, 0])
    group = pd.Series(' '.join(group_data['posts'].get_group(f"{t}")).lower().split()).to_string(index = False)
    group = text_prep(group)
    group_str = ' '.join(group)
    wordcloud = WordCloud(collocations = False, background_color = 'white').generate(group_str)
    ax0.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")

    ax1 = fig.add_subplot(spec[i, 1])
    post_dict = wordcloud.process_text(group_str)
    word_freq={y: s for y, s in sorted(post_dict.items(),reverse=True, key=lambda item: item[1])}
    dist = pd.DataFrame(list(word_freq.items())[:10])
    dist.columns = ["Words", "Count"]
    ax1.bar(x = dist["Words"], height = dist["Count"])
    ax1.tick_params(axis='x', labelrotation = 45)
    ax1.set_xlabel(f"Top 10 Most Used Words by {t} Types")
    ax1.set_ylabel("Count")
    plt.tight_layout()
    plt.title(f"{t}", x = 0, y=1.05, fontsize = 15)
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 5
#       3 for i, t in enumerate(mbti):
#       4     ax0 = fig.add_subplot(spec[i, 0])
# ----> 5     group = pd.Series(' '.join(group_data['posts'].get_group(f"{t}")).lower().split()).to_string(index = False)
#       6     group = text_prep(group)
#       7     group_str = ' '.join(group)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1416, in DataFrameGroupBy.__getitem__(self, key)
#    1407 if isinstance(key, tuple) and len(key) > 1:
#    1408     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1409     # valid syntax, so don't raise warning
#    1410     warnings.warn(
#    1411         "Indexing with multiple keys (implicitly converted to a tuple "
#    1412         "of keys) will be deprecated, use a list instead.",
#    1413         FutureWarning,
#    1414         stacklevel=find_stack_level(),
#    1415     )
# -> 1416 return super().__getitem__(key)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/base.py:248, in SelectionMixin.__getitem__(self, key)
#     246 else:
#     247     if key not in self.obj:
# --> 248         raise KeyError(f"Column not found: {key}")
#     249     subset = self.obj[key]
#     250     ndim = subset.ndim
#
# KeyError: 'Column not found: posts'

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Dividing testing and training

# %%
train, test = model_selection.train_test_split(data, test_size=0.3, random_state = 301)

# %% [markdown]
# #### Visualizing the Training Data Distribution

# %%
train
# Out:
#       type                                                  0  \
# 3938  ISTP  The ISTPs quiet moments didnt seem to bother y...
# 5687  INTP                                      ok thank you!
# 3331  ISTP                                             :wink:
# 7116  INTP  Alright, I'm just bored. So I thought up a gam...
# 1425  INFP                                             Golden
# ...    ...                                                ...
# 2365  INFP  Not married, but I would to either elope or ha...
# 4331  INTJ  So my sick, stiff and introverted self started...
# 3730  INTP  My son and I doing our mad faces at his birth ...
# 1604  ENTP  Any place with craft beers. And sometimes musi...
# 1344  ISTP  I don't know if my opinion would help at all s...
#
#                                                       1  \
# 3938                Dr. Hill - INTJ The Stranger - INTP
# 5687  hmm so 2 gods? that's interesting. Seems probl...
# 3331                                         I'm trying
# 7116  I had a overall happy childhood, I was inquisi...
# 1425                                          Radiohead
# ...                                                 ...
# 2365  I'm assertive when it comes to my ideas, moral...
# 4331  I second this so much! My ISFP boyfriend has d...
# 3730  I'm from NC as well 35 minutes west of Charlot...
# 1604  So I dunno if you could read it from my self d...
# 1344  Well, I don't think he felt I can't believe I ...
#
#                                                       2  \
# 3938  Chris - ENTP Josh - ENFJ Sam - ISFP  Mike - ES...
# 5687  .   So much like 5L you are unable, for this e...
# 3331        I feel like this thread needs more pictures
# 7116  These are all from when I was in elementary sc...
# 1425          Yeahhhhh !!!! Congratulations :D :carrot:
# ...                                                 ...
# 2365  I'm sorry, I feel you. My father is also an es...
# 4331     My ISFP boyfriend and I :).   440162440178 ...
# 3730                                            Love it
# 1604               I'm often intimidated by wild bears.
# 1344  hm.. I actually have a tendency of constantly ...
#
#                                                       3  \
# 3938  I've witnessed the dynamics of these two types...
# 5687  How do you know that? I qualified it as a fict...
# 3331  I just wanted to insert myself into this threa...
# 7116  Depends how they try to help. I can understand...
# 1425                                                  .
# ...                                                 ...
# 2365  The reason why most 9's mistype is because enn...
# 4331  I'm INTJ and I've been dating an ISFP for 5 mo...
# 3730  Naturally ESFJ's why I have no idea they just ...
# 1604  I've found that just asking how they're doing ...
# 1344  I tend to consistently run into INFJs all the ...
#
#                                                       4  \
# 3938  Give me 30 minutes, a gun, an apple and a box ...
# 5687  Argument from authority fallacy. Ones credenti...
# 3331  Please do  and you're welcome   Sent from my i...
# 7116  I have a very strong Fe when it comes to under...
# 1425                            energetic to frustrated
# ...                                                 ...
# 2365  You e8 entj father sounds just like my e8 estj...
# 4331  I've been interested in an intp in the past (f...
# 3730  If your a male and have come to realize that y...
# 1604  Little late to the party, and a little late se...
# 1344  That's actually pretty tough. Well I did read ...
#
#                                                       5  \
# 3938  Who dislikes ENTJs?? Only if your gullible or ...
# 5687  My preference is irrelevant. I personally do n...
# 3331                                    is it July yet?
# 7116  Yes, this sounds like what I am experiencing. ...
# 1425                                   wow :excitement:
# ...                                                 ...
# 2365  Goodness, this is literally my childhood. Exce...
# 4331  I've been romantically involved with an INTJ i...
# 3730  No doubt I find it funny when someone tries to...
# 1604  The most sacrificial thing I will ever do is d...
# 1344  When I get depressed, I get very self-critical...
#
#                                                       6  \
# 3938  ^^^ This! I once used my BB gun on a huge brow...
# 5687  And this is precisely why you need an authorit...
# 3331   and yes we are willing to approve said underwear
# 7116  Serious question, have any of you INTPs experi...
# 1425  Put out fire because i would probably try to t...
# ...                                                 ...
# 2365  I find it so easy to be around intps, they're ...
# 4331                                             255506
# 3730                                  This crap  187386
# 1604                      Occasionally I need a diaper.
# 1344  37210  this is just an update from my previous...
#
#                                                       7  \
# 3938  Use my bare hands. Skin to carapace, guts n al...
# 5687  Faith is unreliable. That‚Äôs why I prefer a r...
# 3331  do not over plan it!  bring sexy underwear! ha...
# 7116  Hey guys, I've been hoping that some of you co...
# 1425                                          Chocolate
# ...                                                 ...
# 2365  Weirdly enough, I don't mind it terribly. I gu...
# 4331  9483894839948409484194842 I am genderfluid and...
# 3730                                     Love the eyes.
# 1604  I am actually your guardian angel speaking to ...
# 1344  Hmm... I'm usually pretty welcoming person fro...
#
#                                                       8  ...   50   51   52  \
# 3938                          I dont get it. Violence??  ...  NaN  NaN  NaN
# 5687  I am an atheist, and yet my life is not empty ...  ...  NaN  NaN  NaN
# 3331  Keep in mind everyone is different and this is...  ...  NaN  NaN  NaN
# 7116  I went into university loving science, but was...  ...  NaN  NaN  NaN
# 1425               Energised and ready to fight the day  ...  NaN  NaN  NaN
# ...                                                 ...  ...  ...  ...  ...
# 2365                 Librarylady Are you a 9 perchance?  ...  NaN  NaN  NaN
# 4331                                                  .  ...  NaN  NaN  NaN
# 3730                          Lol yes the phone. :wink:  ...  NaN  NaN  NaN
# 1604                              Do you do butt stuff?  ...  NaN  NaN  NaN
# 1344  dude. My ENFP gf said to me (or claimed) that ...  ...  NaN  NaN  NaN
#
#        53   54   55   56   57   58 Word Count
# 3938  NaN  NaN  NaN  NaN  NaN  NaN       1242
# 5687  NaN  NaN  NaN  NaN  NaN  NaN       1533
# 3331  NaN  NaN  NaN  NaN  NaN  NaN        834
# 7116  NaN  NaN  NaN  NaN  NaN  NaN       2014
# 1425  NaN  NaN  NaN  NaN  NaN  NaN        517
# ...   ...  ...  ...  ...  ...  ...        ...
# 2365  NaN  NaN  NaN  NaN  NaN  NaN       1960
# 4331  NaN  NaN  NaN  NaN  NaN  NaN       1423
# 3730  NaN  NaN  NaN  NaN  NaN  NaN       1052
# 1604  NaN  NaN  NaN  NaN  NaN  NaN       1607
# 1344  NaN  NaN  NaN  NaN  NaN  NaN       1753
#
# [6072 rows x 61 columns]

# %%
group_train = train.groupby('type')

n_train = []
for x in mbti:
    num_rows = len(group_train.get_group(f"{x}"))
    n_train += [num_rows]
    
n_train_obs = pd.DataFrame([np.array(mbti), np.array(n_train)]).T
n_train_obs.columns = ["type", "n obeservations"]

# %%
plt.subplots(figsize= (9,5))
ax = sns.countplot(train, x = "type", order = mbti)
ax.bar_label(ax.containers[0], labels = n_train)
plt.xlabel("MBTI Type")
plt.ylabel("Number of Observations")
plt.title("Representation of Each MBTI in Training Data")
# Out:
# Text(0.5, 1.0, 'Representation of Each MBTI in Training Data')
